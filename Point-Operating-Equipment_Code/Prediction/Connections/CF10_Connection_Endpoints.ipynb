# %% [markdown]
# 09/07/2020
#
# ### Purpose : To specify connection points for different teams to use consistently
#
#  include below command as first cell in your notebook
#
#  **%run /Shared/Connections/file_name**

# %%
##13/07/2020
###################################################################################
## Purpose : To specify connection points for different teams to use consistently


##Connection to ADLS  stgiiinnovationppinv

spark.conf.set(
"fs.azure.account.key.stgiiinnovationppinv.dfs.core.windows.net",
"R9byP7oOLmxW4Y66vAcLG8WAf9mbzYnadJnt9j4Bf/WHiqqKh0zqqFo7Y3ePF4J6zOHP4k7dAlgmLpdPx7BetA=="
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
###################################################################################
## Connection endpoint for Azure Data Store (ADS)


jdbcHostname = "sqliidstpochub001.database.windows.net" 
jdbcDatabase = "ADS_Data_Mart"
jdbcPort = 1433

username = dbutils.secrets.get(scope = "dbrksKvInnovScope", key = "TRACKDSTDEV-INNOVPP-USER")
password = dbutils.secrets.get(scope = "dbrksKvInnovScope", key = "TRACKDSTDEV-INNOVPP-PASSWORD")
jdbcUrl = "jdbc:sqlserver://{0}:{1};database={2};user={3};password={4}".format(jdbcHostname, jdbcPort, jdbcDatabase, username, password)

connectionProperties = {
  "user" : username,
  "password" : password,
  "driver" : "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
innvHostname = "sqliiinnovationppinvellipse.database.windows.net"
innvDatabase = "sdbiiinnovationppinvellipse"
innvPort = 1433
innvUrl = "jdbc:sqlserver://{0}:{1};database={2}".format(innvHostname, innvPort, innvDatabase)
properties = {
 "user" : "InnovationdB_Admin",
 "password" : "WjHtIM4fZ#8[h!Y",
 "driver" : "com.microsoft.sqlserver.jdbc.SQLServerDriver"
 }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
