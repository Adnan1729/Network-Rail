# %% [markdown]
# 09/07/2020
#
# ### Purpose : To define parameters for consistent use across teams
#
#  include below command as first cell in your notebook
#
#  %run /Shared/Connections/file_name

# %%
## Storage Account

##Storage account name
vStrgacc_name = "cf10@stgiiinnovationppinv"
vSrc_CDMS_name = "nrii-cur-cdms@stgiidstpochub001"

## root path name
vStrgacc_root = "/mnt/" + vStrgacc_name + "/"

## reference file location
vStrgacc_ref = "/mnt/" + vStrgacc_name + "/ref/"  
vStrgacc_prd = "/mnt/" + vStrgacc_name + "/stage/WWHistory-LNW/"
vStage_rcf = "/mnt/" + vStrgacc_name + "/stage_rcf/cdms_raw_files/"
vSrc_CDMS_AllignmentFile="/mnt/" + vSrc_CDMS_name + "/"


print ("vStrgacc_name = ", vStrgacc_name)
print ("vStrgacc_root = ", vStrgacc_root)
print ("vStrgacc_ref = ", vStrgacc_ref)
print ("vStrgacc_prd = ", vStrgacc_prd)
print ("vStage_rcf = ", vStage_rcf)
print ("vSrc_CDMS_AllignmentFile=",vSrc_CDMS_AllignmentFile)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">vStrgacc_name =  cf10@stgiiinnovationppinv
# vStrgacc_root =  /mnt/cf10@stgiiinnovationppinv/
# vStrgacc_ref =  /mnt/cf10@stgiiinnovationppinv/ref/
# vStrgacc_prd =  /mnt/cf10@stgiiinnovationppinv/stage/WWHistory-LNW/
# </div>

# %%
## SQL Server

## Available for 51 assets

## flat structure containing FMS and Asset data
vSQL_Asset_FMS =  "DST.v_cf10_AssetFMS"

## flat structure containing WorkOrder and Asset data
vSQL_Asset_WO = "DST.v_cf10_AssetWorkorder"

print ("vSQL_Asset_FMS =", vSQL_Asset_FMS)
print ("vSQL_Asset_WO =", vSQL_Asset_WO)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">vSQL_Asset_FMS = DST.v_cf10_AssetFMS
# vSQL_Asset_WO = DST.v_cf10_AssetWorkorder
# </div>
